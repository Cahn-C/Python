# %% [markdown]
# # <b>What is a Function</b>
#
# Formally, a function is a useful device that groups together a set of statements so they can be run more than once. We can specify parameters that can server as inputs to the functions
#
# On a more fundamental level, functions allow us to not have to repeatedly write the same code again and again.
#
# Functions will be one of the most basic levels of reusing code in Python, and it will also allow us to start thinking of program design.

# %% [markdown]
# ## <b>Function Definition</b>
#
# In the syntax below:
#   - `def` is the keyword used to define functions
#   - arg1 ...argn, *args and **kwargs are functino parameters(and are optional)
#   - The expression after the `return` keyword is the value returned to the caller(optional)
#
# <br>
#
#   <center><img src="data:image/png;base64,..."></center>

# %%
def name_of_function(arg1, arg2):
  '''
  This is where the function's Document String (doc-string) goes
  '''

  # Do stuff here
  # return desired result

# %% [markdown]
# ## `def` Statements
#
# We begin with def then a space followed by the name of the function. Try to keep names relevent, for example `len()` is a good name for `length()` function. Also be careful with names, you wouldn't want to call a function the same name as a built-in function in Python(such as len)
#
# Next come a pair of parenthesis with a nummber of arguments seperated by a comma. These arguments are the input for your function and reference them. After this put a colon
#
# Next you'll see the doc-string, this is where you write a basic description of the function. Using iPython and iPython Notebooks, you'll be able to read these doc-strings by pressing `Shift+Tab` after a function name. Doc strings are not necessary for simple functions, but its good practice to put them in so you or other people can easily understand the code your write

# %% [markdown]
# ## <b>Example 1: A simple print 'hello' function</b>

# %%
def say_hello():
  print("hello")

# call the function
print(say_hello())
# Out:
# hello
# None

# %% [markdown]
# ## <b>Function Argument</b>
#
# - Parameter may or may not have default values
# - A function parameter can be passed either by position or by key/name
# - A function can accept a variable number of positional arguments(*args)
# - A function can accept a variable number of keyword arguments(**kwargs)
# - Function parameters are passed by object reference

# %% [markdown]
# ## <b>Default Arguments / Keyword Arguments</b>
#
# - Default arguments are those arguments which can be changed but their value remains the same if not given.

# %%
def double_the_number(num = 1):
  return num * 2

print(double_the_number())
# Out:
# 2

# %%
print(double_the_number(8))
# Out:
# 16

# %%
def database_columns(*args): # *args is a dynamic way of adding more arguemts into the function
  for arg in args:
    print(arg)

# %%
database_columns("EmployeeID", "EmployeeName", "HireDate", "BirthDate", "Manager")
# Out:
# EmployeeID
# EmployeeName
# HireDate
# BirthDate
# Manager

# %% [markdown]
# ## <b>Positional Arguments</b>
#
# - Positional Arguments are those which are not followed by an equal sign(=) and default value. In this we need to provide an argument while calling the function, else we get an error

# %%
def double_the_number(num):
  return num * 2

print(double_the_number(2))
# Out:
# 4

# %% [markdown]
# ## <b>Important Tip</b>
#
# - <b>Positional arguments</b> will always <b>precede Keyword argumetns</b> while specifying both of them together in the same function.

# %%
def database_columns(**kwargs):
  for value in kwargs.items():
    print(value)

# %%
database_columns(name = "Chaanyah", age = "25")
# Out:
# ('name', 'Chaanyah')
# ('age', '25')

# %% [markdown]
# ## <b>`return` Values</b>
#
# A Return value is a value that is returned after performing a specific operation in a function. Some advantages and usecases of return values are as follows:
#
#   - Unlike some other languages, Python allows returning multiple values
#   - However, the multiple values is just a tuple of values
#   - Because of this, the tuple can simply be "opened" into multiple variables

# %%
def get_my_name(name):
  return name * 5

# %%
print(get_my_name("Chaanyah"))
# Out:
# ChaanyahChaanyahChaanyahChaanyahChaanyah
